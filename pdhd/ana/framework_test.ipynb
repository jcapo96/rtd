# %%
import matplotlib.pyplot as plt
import pandas as pd
from src import baseClasses, systemClasses, sensorClasses, muxClasses
import datetime

# %%
dataset = baseClasses.Data()

# %%
s1 = sensorClasses.Sensor(dataset=dataset, id=44114).muxEqualization().tempCalibration(calibName="SECOND_POFF_TGRAD_HAWAI_APA_CE_OFF_REC_OFF_HV_OFF_20241203_132500_20241203_142500")
# s1.muxEqualization()
# s1.tempCalibration()
print(s1.equalizationInfo)
# print(s1.is_mux_equalized)
plt.plot(s1.data, ".")
plt.xlim(datetime.datetime(2024, 5, 1, 12, 0, 0), datetime.datetime(2024, 5, 3, 14, 30, 0))
plt.ylim(86.5, 87.15)
plt.xticks(rotation=45);
# Out:
# ERROR: Board (11) not found
# ERROR: Board (11) not found in equalization (FIRST_POFF_39644_39619_39614_40200_39607_39669)
# ERROR: Board (11) not found
# ERROR: Board (11) not found in equalization (FIRST_POFF_39644_39619_39614_40200_39607_39669)
# ERROR: Board (11) not found
# ERROR: Board (11) not found in equalization (FIRST_POFF_39644_39619_39614_40200_39607_39669)
# {1: 1, 2: -1.0000132804223354, 3: -1.0000195188684993, 4: -0.24888192262580003}
